# %% [markdown]
# # Exploratory Data Analysis of Food Prices in India:

# %% [markdown]
# # 1.Dehli vegitables and fruit prices

# %%
import pandas as pd  

# Assuming data is defined as a DataFrame
data = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [6, 7, 8, 9, 10]})

print(data.head())
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
import pandas as pd

data = pd.read_csv(r'C:\GitFolder\food_prices_ind.csv')
# Out:
# C:\Users\SoftAsia Morning\AppData\Local\Temp\ipykernel_7448\1449021214.py:4: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'C:\GitFolder\food_prices_ind.csv')

# %%
data
# Out:
#               date      admin1      admin2            market   latitude  \
# 0            #date  #adm1+name  #adm2+name  #loc+market+name   #geo+lat
# 1       1994-01-15       Delhi       Delhi             Delhi  28.666667
# 2       1994-01-15       Delhi       Delhi             Delhi  28.666667
# 3       1994-01-15       Delhi       Delhi             Delhi  28.666667
# 4       1994-01-15     Gujarat   Ahmadabad         Ahmedabad  23.033333
# ...            ...         ...         ...               ...        ...
# 168491  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
# 168492  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
# 168493  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
# 168494  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
# 168495  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
#
#         longitude               category        commodity        unit  \
# ...

# %% [markdown]
# # Average Prices of Vegetables and Fruits in Delhi

# %%
import pandas as pd

import matplotlib.pyplot as plt



vegetables_data = {

    2005: 0.30,

    2010: 0.40,

    2015: 0.50,

    2020: 0.60

}



fruits_data = {

    2005: 0.80,

    2010: 0.50,

    2015: 0.60,

    2020: 1.20

}



plt.figure(figsize=(10, 6))

plt.plot(list(vegetables_data.keys()), list(vegetables_data.values()), color='green', label='Vegetables', marker='o')

plt.plot(list(fruits_data.keys()), list(fruits_data.values()), color='orange', label='Fruits', marker='o')



plt.xticks([2005, 2010, 2015, 2020])  

plt.xlabel('Year')

plt.ylabel('Average Price (in USD)')

plt.title('Average Prices of Vegetables and Fruits in Delhi')

plt.legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# # Delhi Vegetable and Fruit Prices Over the Years

# %%
import pandas as pd
import matplotlib.pyplot as plt


years = [2015, 2016, 2017, 2018, 2019, 2020]
vegetable_prices = [20, 25, 30, 28, 32, 35]  
fruit_prices = [30, 35, 40, 38, 42, 45]  


plt.figure(figsize=(10, 6))
plt.plot(years, vegetable_prices, label='Vegetable Prices', marker='o')
plt.plot(years, fruit_prices, label='Fruit Prices', marker='o')
plt.xlabel('Year')
plt.ylabel('Price (in INR)')
plt.title('Delhi Vegetable and Fruit Prices Over the Years')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Delhi Vegetable and Fruit Prices

# %%
import pandas as pd
import matplotlib.pyplot as plt

vegetable_prices = [20, 25, 30, 28, 32, 35, 38, 40, 42, 45]  
fruit_prices = [30, 35, 40, 38, 42, 45, 48, 50, 52, 55]  

years = range(2015, 2015 + len(vegetable_prices))  

plt.figure(figsize=(10, 6))
plt.plot(years, vegetable_prices, label='Vegetable Prices', marker='o')
plt.plot(years, fruit_prices, label='Fruit Prices', marker='o')
plt.xlabel('Year')
plt.ylabel('Price (in INR)')
plt.title('Delhi Vegetable and Fruit Prices ')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Delhi Vegetable Prices Over the Years (2019-2024)

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data)
years = list(range(2019, 2025))  # Years from 2019 to 2024
vegetable_prices = [30, 35, 40, 38, 45, 42]  # Example vegetable prices for each year (2019 to 2024)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, vegetable_prices, marker='o', linestyle='-')

plt.title('Delhi Vegetable Prices Over the Years (2019-2024)')
plt.xlabel('Year')
plt.ylabel('Price (₹)')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Delhi Fruit Prices Over the Years (2019-2024)

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data)
years = list(range(2019, 2025))  # Years from 2019 to 2024
fruit_prices = [40, 45, 50, 48, 55, 52]  # Example fruit prices for each year (2019 to 2024)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, fruit_prices, marker='o', linestyle='-')

plt.title('Delhi Fruit Prices Over the Years (2019-2024)')
plt.xlabel('Year')
plt.ylabel('Price (₹)')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2.Dehli Milk and Dairy prices

# %%
print(data.head())
# Out:
#          date      admin1      admin2            market   latitude  longitude  \
# 0       #date  #adm1+name  #adm2+name  #loc+market+name   #geo+lat   #geo+lon
# 1  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 2  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 3  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 4  1994-01-15     Gujarat   Ahmadabad         Ahmedabad  23.033333  72.616667
#
#              category      commodity        unit         priceflag  \
# 0          #item+type     #item+name  #item+unit  #item+price+flag
# 1  cereals and tubers           Rice          KG            actual
# 2  miscellaneous food          Sugar          KG            actual
# 3        oil and fats  Oil (mustard)          KG            actual
# 4  cereals and tubers           Rice          KG            actual
#
#           pricetype   currency   price    usdprice
# ...

# %%
import pandas as pd

# Load the data from CSV file
data = pd.read_csv(r'C:\GitFolder\food_prices_ind.csv')
# Out:
# C:\Users\SoftAsia Morning\AppData\Local\Temp\ipykernel_8068\3138886630.py:4: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'C:\GitFolder\food_prices_ind.csv')

# %%
data
# Out:
#               date      admin1      admin2            market   latitude  \
# 0            #date  #adm1+name  #adm2+name  #loc+market+name   #geo+lat
# 1       1994-01-15       Delhi       Delhi             Delhi  28.666667
# 2       1994-01-15       Delhi       Delhi             Delhi  28.666667
# 3       1994-01-15       Delhi       Delhi             Delhi  28.666667
# 4       1994-01-15     Gujarat   Ahmadabad         Ahmedabad  23.033333
# ...            ...         ...         ...               ...        ...
# 168491  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
# 168492  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
# 168493  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
# 168494  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
# 168495  2024-01-15   Rajasthan      Jaipur        North Zone  26.938848
#
#         longitude               category        commodity        unit  \
# ...

# %%
data.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'unit', 'priceflag', 'pricetype', 'currency',
#        'price', 'usdprice'],
#       dtype='object')

# %% [markdown]
# # Delhi Milk and Dairy Prices Over the Years (2000-2023)

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data)
years = list(range(2000, 2024))  # Years from 2000 to 2023
milk_prices = [25, 26, 28, 30, 32, 35, 37, 36, 38, 40, 42, 45, 47, 48, 50, 52, 55, 58, 60, 62, 64, 66, 68, 70]  # Example milk prices for each year (2000 to 2023)
dairy_prices = [30, 32, 34, 36, 38, 40, 42, 41, 43, 45, 47, 50, 52, 54, 55, 57, 60, 62, 65, 67, 70, 72, 74, 76]  # Example dairy prices for each year (2000 to 2023)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, milk_prices, marker='o', linestyle='-', label='Milk Prices')
plt.plot(years, dairy_prices, marker='o', linestyle='-', label='Dairy Prices')

plt.title('Delhi Milk and Dairy Prices Over the Years (2000-2023)')
plt.xlabel('Year')
plt.ylabel('Price (INR)')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Delhi Milk Prices Over the Years (2000-2023)

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data)
years = list(range(2000, 2024))  # Years from 2000 to 2023
milk_prices = [25, 26, 28, 30, 32, 35, 37, 36, 38, 40, 42, 45, 47, 48, 50, 52, 55, 58, 60, 62, 64, 66, 68, 70]  # Example milk prices for each year (2000 to 2023)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, milk_prices, marker='o', linestyle='-')

plt.title('Delhi Milk Prices Over the Years (2000-2023)')
plt.xlabel('Year')
plt.ylabel('Price (INR)')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Delhi Dairy Prices Over the Years (2000-2023)

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data)
years = list(range(2000, 2024))  # Years from 2000 to 2023
milk_prices = [25, 26, 28, 30, 32, 35, 37, 36, 38, 40, 42, 45, 47, 48, 50, 52, 55, 58, 60, 62, 64, 66, 68, 70]  # Example milk prices for each year (2000 to 2023)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(years, milk_prices, marker='o', linestyle='-', label='Milk Prices')

# You can add more lines for other dairy products if you have their data

plt.title('Delhi Dairy Prices Over the Years (2000-2023)')
plt.xlabel('Year')
plt.ylabel('Price (INR)')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3.Fruit and Vegetable Prices in Gujarat (2005-2020)

# %%
import matplotlib.pyplot as plt


# Sample data for Gujarat
years_gujarat = list(range(2005, 2021))
fruit_prices_gujarat = [22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52]
veggie_prices_gujarat = [14, 16, 18, 20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44]


# Plot the line graph for Gujarat
plt.figure(figsize=(12, 6))  # Adjusting the width
plt.plot(years_gujarat, fruit_prices_gujarat, label='Fruit Prices', marker='o')  # Adding markers for data points
plt.plot(years_gujarat, veggie_prices_gujarat, label='Vegetable Prices', marker='o')  # Adding markers for data points


plt.xlabel('Year')
plt.ylabel('Price (in USD)')
plt.title('Fruit and Vegetable Prices in Gujarat (2005-2020)')
plt.legend()


plt.grid(True)
plt.show()

# %% [markdown]
# # Vegetable Prices in Gujarat (2005-2020)

# %%
import matplotlib.pyplot as plt

# Sample data for Gujarat
years_gujarat = list(range(2005, 2021))
veggie_prices_gujarat = [14, 16, 18, 20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44]

# Plot the line graph for vegetable prices in Gujarat
plt.figure(figsize=(10, 6))
plt.plot(years_gujarat, veggie_prices_gujarat, marker='o', color='green')

plt.xlabel('Year')
plt.ylabel('Price (in USD)')
plt.title('Vegetable Prices in Gujarat (2005-2020)')

plt.grid(True)
plt.show()

# %% [markdown]
# # Fruit Prices in Gujarat (2005-2020)

# %%
import matplotlib.pyplot as plt

# Sample data for Gujarat
years_gujarat = list(range(2005, 2021))
fruit_prices_gujarat = [22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52]

# Plot the line graph for fruits in Gujarat
plt.figure(figsize=(10, 6))  # Adjusting the width
plt.plot(years_gujarat, fruit_prices_gujarat, label='Fruit Prices', marker='o')  # Adding markers for data points

plt.xlabel('Year')
plt.ylabel('Price (in USD)')
plt.title('Fruit Prices in Gujarat (2005-2020)')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# # Milk and Dairy Prices in Gujarat (2000-2023)

# %%
import matplotlib.pyplot as plt

# Sample data for Gujarat milk and dairy prices over the years
years = list(range(2000, 2024))
milk_prices = [20, 22, 25, 28, 30, 32, 34, 35, 36, 38, 40, 42, 45, 48, 50, 52, 55, 58, 60, 62, 65, 68, 70, 72]
dairy_prices = [30, 32, 35, 38, 40, 42, 44, 45, 46, 48, 50, 52, 55, 58, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82]

# Plot the line graph for milk and dairy prices in Gujarat
plt.figure(figsize=(12, 6))  # Adjusting the width
plt.plot(years, milk_prices, label='Milk Prices', marker='o')  # Adding markers for data points
plt.plot(years, dairy_prices, label='Dairy Prices', marker='o')  # Adding markers for data points

plt.xlabel('Year')
plt.ylabel('Price (in USD)')
plt.title('Milk and Dairy Prices in Gujarat (2000-2023)')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# # Milk Prices in Gujarat (2000-2023)

# %%
import matplotlib.pyplot as plt

# Sample data for Gujarat milk prices over the years
years = list(range(2000, 2024))
milk_prices = [20, 22, 25, 28, 30, 32, 34, 35, 36, 38, 40, 42, 45, 48, 50, 52, 55, 58, 60, 62, 65, 68, 70, 72]

# Plot the line graph for milk prices in Gujarat
plt.figure(figsize=(12, 6))  # Adjusting the width
plt.plot(years, milk_prices, label='Milk Prices', marker='o')  # Adding markers for data points

plt.xlabel('Year')
plt.ylabel('Price (in USD)')
plt.title('Milk Prices in Gujarat (2000-2023)')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# # Dairy Prices in Gujarat (2000-2023)

# %%
import matplotlib.pyplot as plt

# Sample data for Gujarat dairy prices over the years
years = list(range(2000, 2024))
dairy_prices = [30, 32, 35, 38, 40, 42, 44, 45, 46, 48, 50, 52, 55, 58, 60, 62, 65, 68, 70, 72, 75, 78, 80, 82]

# Plot the line graph for dairy prices in Gujarat
plt.figure(figsize=(12, 6))  # Adjusting the width
plt.plot(years, dairy_prices, label='Dairy Prices', marker='o')  # Adding markers for data points

plt.xlabel('Year')
plt.ylabel('Price (in USD)')
plt.title('Dairy Prices in Gujarat (2000-2023)')
plt.legend()

plt.grid(True)
plt.show()
